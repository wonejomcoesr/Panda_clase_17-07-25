# %% [markdown]
# <a href="https://colab.research.google.com/github/wonejomcoesr/Panda_clase_17-07-25/blob/main/Panda_clase17_07_25.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Trabajando con Panda**

# %%
import pandas as pd

# %%
#Ayuda especifica dentro de panda
help(pd.Series.iloc)
# Out:
# Help on property:
#
#     Purely integer-location based indexing for selection by position.
#
#     .. deprecated:: 2.2.0
#
#        Returning a tuple from a callable is deprecated.
#
#     ``.iloc[]`` is primarily integer position based (from ``0`` to
#     ``length-1`` of the axis), but may also be used with a boolean
#     array.
#
#     Allowed inputs are:
#
#     - An integer, e.g. ``5``.
#     - A list or array of integers, e.g. ``[4, 3, 0]``.
#     - A slice object with ints, e.g. ``1:7``.
#     - A boolean array.
#     - A ``callable`` function with one argument (the calling Series or
#       DataFrame) and that returns valid output for indexing (one of the above).
#       This is useful in method chains, when you don't have a reference to the
#       calling object, but would like to base your selection on
#       some value.
#     - A tuple of row and column indexes. The tuple elements consist of one of the
#       above inputs, e.g. ``(0, 1)``.
#
# ...

# %% [markdown]
# **Toma de contactos**

# %%
diccionario = [{'a':2,'b':4,'c':9},{'A':16,'B':12,'C':19}]
df=pd.DataFrame(diccionario)
df
# Out:
#      a    b    c     A     B     C
# 0  2.0  4.0  9.0   NaN   NaN   NaN
# 1  NaN  NaN  NaN  16.0  12.0  19.0

# %% [markdown]
# **Series**

# %%
#Crear series
serie=pd.Series([2,6,-1,8,9,2.3],index=['a','b','c','d','e','f'])
serie
# Out:
# a    2.0
# b    6.0
# c   -1.0
# d    8.0
# e    9.0
# f    2.3
# dtype: float64

# %%
#Borrar series (filas)
serie2=serie.drop(['a','e'])
serie2
# Out:
# b    6.0
# c   -1.0
# d    8.0
# f    2.3
# dtype: float64

# %%
#Seleccionar series (filas)
serie[['b','d']]
# Out:
# b    6.0
# d    8.0
# dtype: float64

# %%
#Asignar nuevos valores
serie['b']=100
serie
# Out:
# a      2.0
# b    100.0
# c     -1.0
# d      8.0
# e      9.0
# f      2.3
# dtype: float64

# %%
#Operadores
#Suma
serie3=serie+serie2
serie3
# Out:
# a      NaN
# b    106.0
# c     -2.0
# d     16.0
# e      NaN
# f      4.6
# dtype: float64

# %%
#Resta
serie.sub(serie2)
# Out:
# a     NaN
# b    94.0
# c     0.0
# d     0.0
# e     NaN
# f     0.0
# dtype: float64

# %%
#Multiplicacion
serie.mul(serie2)
# Out:
# a       NaN
# b    600.00
# c      1.00
# d     64.00
# e       NaN
# f      5.29
# dtype: float64

# %%
#Division
serie.div(serie2)
# Out:
# a          NaN
# b    16.666667
# c     1.000000
# d     1.000000
# e          NaN
# f     1.000000
# dtype: float64

# %%
#Resto de la division
serie.mod(serie2)
# Out:
# a    NaN
# b    4.0
# c   -0.0
# d    0.0
# e    NaN
# f    0.0
# dtype: float64

# %% [markdown]
# **Data frames**

# %%
datos={'Alumno':['M mar','Lucia','Juan','Eva'],'Nota':[20,10,15,8]}
df=pd.DataFrame(datos,columns=['Alumno','Nota'])
df
# Out:
#   Alumno  Nota
# 0  M mar    20
# 1  Lucia    10
# 2   Juan    15
# 3    Eva     8

# %%
#Eliminar la columna 2
df2 = df.drop('Nota', axis=1)
print(df2)
# Out:
#   Alumno
# 0  M mar
# 1  Lucia
# 2   Juan
# 3    Eva

# %%
#Cambiar l anota de Eva
df.loc[df['Alumno'] == 'Eva', 'Nota'] = 20
df
# Out:
#   Alumno  Nota
# 0  M mar    20
# 1  Lucia    10
# 2   Juan    15
# 3    Eva    20

# %%
#Seleccionar series (filas)
df_selected = df.loc[df['Alumno'].isin(['M mar', 'Juan'])]

print(df_selected)
# Out:
#   Alumno  Nota
# 0  M mar    20
# 2   Juan    15

# %% [markdown]
# **Entrada, salida y escritura**

# %%
#Grabar un dataframe
df.to_csv('/content/misDatos.csv',index=False,columns=['Alumno','Nota'])

# %%
#Leer el dataframe
mis_datos=pd.read.csv('/content/misDatos.csv',header=None,nrows=2)
mis_datos.columns=['Alumno','Nota']
mis_datos.head()
